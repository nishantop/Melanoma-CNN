# %% [markdown]
# **Problem statement**: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Motivation**: To create a multiclass classification model using a custom convolutional neural network in tensorflow

# %% [markdown]
# **Data Summary:**
#
# The dataset consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC, and all subsets were divided into the same number of images, with the exception of melanomas and moles, whose images are slightly dominant.
#
# The data set contains the following diseases:
# 1. Actinic keratosis
# 2. Basal cell carcinoma
# 3. Dermatofibroma
# 4. Melanoma
# 5. Nevus
# 6. Pigmented benign keratosis
# 7. Seborrheic keratosis
# 8. Squamous cell carcinoma
# 9. Vascular lesion

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding

# %%
## If you are using the data by mounting the google drive, use the following :

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
root_path = '/content/gdrive/MyDrive/CNN/Skin_Data_Store'
data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_test = pathlib.Path(root_path + '/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3))
]

# %%
### Your code goes here

input_shape = (180,180,3)
lr = 1e-5
init = 'normal'
activ = 'relu'

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(180, 180, 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

## Number of classes is 9
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrapp  (None, 178, 178, 32)     896
#  er)
#
#  module_wrapper_1 (ModuleWra  (None, 176, 176, 32)     9248
#  pper)
#
#  module_wrapper_2 (ModuleWra  (None, 88, 88, 32)       0
#  pper)
#
#  module_wrapper_3 (ModuleWra  (None, 86, 86, 64)       18496
#  pper)
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  module_wrapper_4 (ModuleWra  (None, 43, 43, 64)       0
#  pper)
#
#  module_wrapper_5 (ModuleWra  (None, 41, 41, 128)      73856
#  pper)
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  module_wrapper_6 (ModuleWra  (None, 20, 20, 128)      0
#  pper)
#
#  module_wrapper_7 (ModuleWra  (None, 51200)            0
#  pper)
#
#  module_wrapper_8 (ModuleWra  (None, 512)              26214912
#  pper)
#
#  module_wrapper_9 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_10 (ModuleWr  (None, 512)              0
#  apper)
#
#  module_wrapper_11 (ModuleWr  (None, 1)                513
#  apper)
#
#  module_wrapper_12 (ModuleWr  (None, 1)                0
#  apper)
#
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function

optimizer = 'adam'
loss_fn = "binary_crossentropy"
model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  module_wrapper (ModuleWrapp  (None, 178, 178, 32)     896
#  er)
#
#  module_wrapper_1 (ModuleWra  (None, 176, 176, 32)     9248
#  pper)
#
#  module_wrapper_2 (ModuleWra  (None, 88, 88, 32)       0
#  pper)
#
#  module_wrapper_3 (ModuleWra  (None, 86, 86, 64)       18496
#  pper)
#
#  batch_normalization (BatchN  (None, 86, 86, 64)       256
#  ormalization)
#
#  module_wrapper_4 (ModuleWra  (None, 43, 43, 64)       0
#  pper)
#
#  module_wrapper_5 (ModuleWra  (None, 41, 41, 128)      73856
#  pper)
#
#  batch_normalization_1 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  module_wrapper_6 (ModuleWra  (None, 20, 20, 128)      0
#  pper)
#
#  module_wrapper_7 (ModuleWra  (None, 51200)            0
#  pper)
#
#  module_wrapper_8 (ModuleWra  (None, 512)              26214912
#  pper)
#
#  module_wrapper_9 (ModuleWra  (None, 512)              0
#  pper)
#
#  module_wrapper_10 (ModuleWr  (None, 512)              0
#  apper)
#
#  module_wrapper_11 (ModuleWr  (None, 1)                513
#  apper)
#
#  module_wrapper_12 (ModuleWr  (None, 1)                0
#  apper)
#
# =================================================================
# Total params: 26,318,689
# Trainable params: 26,318,305
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
batch_size = 32

history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 47s 118ms/step - loss: -1377852.5000 - accuracy: 0.1328 - val_loss: -3847312.5000 - val_accuracy: 0.1151
# Epoch 2/20
# 169/169 [==============================] - 11s 67ms/step - loss: -16665831.0000 - accuracy: 0.1337 - val_loss: -35546204.0000 - val_accuracy: 0.1151
# Epoch 3/20
# 169/169 [==============================] - 11s 67ms/step - loss: -66148044.0000 - accuracy: 0.1337 - val_loss: -81716032.0000 - val_accuracy: 0.1151
# Epoch 4/20
# 169/169 [==============================] - 11s 68ms/step - loss: -168390144.0000 - accuracy: 0.1337 - val_loss: -229594528.0000 - val_accuracy: 0.1151
# Epoch 5/20
# 169/169 [==============================] - 12s 68ms/step - loss: -338524672.0000 - accuracy: 0.1337 - val_loss: -627679360.0000 - val_accuracy: 0.1151
# Epoch 6/20
# 169/169 [==============================] - 12s 68ms/step - loss: -592950592.0000 - accuracy: 0.1337 - val_loss: -888115776.0000 - val_accuracy: 0.1151
# Epoch 7/20
# 169/169 [==============================] - 12s 69ms/step - loss: -937890560.0000 - accuracy: 0.1337 - val_loss: -1124616832.0000 - val_accuracy: 0.1151
# Epoch 8/20
# 169/169 [==============================] - 12s 69ms/step - loss: -1384066048.0000 - accuracy: 0.1337 - val_loss: -1868299136.0000 - val_accuracy: 0.1151
# Epoch 9/20
# 169/169 [==============================] - 12s 69ms/step - loss: -1932699648.0000 - accuracy: 0.1337 - val_loss: -2627613440.0000 - val_accuracy: 0.1151
# Epoch 10/20
# 169/169 [==============================] - 12s 70ms/step - loss: -2607511808.0000 - accuracy: 0.1337 - val_loss: -3870033152.0000 - val_accuracy: 0.1151
# Epoch 11/20
# 169/169 [==============================] - 12s 69ms/step - loss: -3401620992.0000 - accuracy: 0.1337 - val_loss: -3664037888.0000 - val_accuracy: 0.1151
# Epoch 12/20
# 169/169 [==============================] - 12s 69ms/step - loss: -4308846080.0000 - accuracy: 0.1337 - val_loss: -4355494912.0000 - val_accuracy: 0.1151
# Epoch 13/20
# 169/169 [==============================] - 12s 69ms/step - loss: -5374822912.0000 - accuracy: 0.1337 - val_loss: -6105356288.0000 - val_accuracy: 0.1151
# Epoch 14/20
# 169/169 [==============================] - 12s 69ms/step - loss: -6535536128.0000 - accuracy: 0.1337 - val_loss: -6398165504.0000 - val_accuracy: 0.1151
# Epoch 15/20
# 169/169 [==============================] - 12s 69ms/step - loss: -7873038336.0000 - accuracy: 0.1337 - val_loss: -10245771264.0000 - val_accuracy: 0.1151
# Epoch 16/20
# 169/169 [==============================] - 12s 69ms/step - loss: -9306122240.0000 - accuracy: 0.1337 - val_loss: -10885801984.0000 - val_accuracy: 0.1151
# Epoch 17/20
# 169/169 [==============================] - 12s 70ms/step - loss: -10927570944.0000 - accuracy: 0.1337 - val_loss: -11629692928.0000 - val_accuracy: 0.1151
# Epoch 18/20
# 169/169 [==============================] - 12s 70ms/step - loss: -12710301696.0000 - accuracy: 0.1337 - val_loss: -12752368640.0000 - val_accuracy: 0.1151
# Epoch 19/20
# 169/169 [==============================] - 12s 70ms/step - loss: -14620069888.0000 - accuracy: 0.1337 - val_loss: -12801318912.0000 - val_accuracy: 0.1151
# Epoch 20/20
# 169/169 [==============================] - 12s 70ms/step - loss: -16654245888.0000 - accuracy: 0.1337 - val_loss: -17228410880.0000 - val_accuracy: 0.1151

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Model Overfit or Underfit?

# %%
loss, accuracy = model.evaluate(train_ds, verbose=1,)
loss_v, accuracy_v = model.evaluate(val_ds, verbose=1)

print("Accuracy: ", accuracy)
print("Validation Accuracy: ",accuracy_v)
print("Loss: ",loss)
print("Validation Loss", loss_v)


# Thus we can clearly that model Overfit and we need to chose right data augumentation strategy
# Out:
# 169/169 [==============================] - 3s 17ms/step - loss: -16917691392.0000 - accuracy: 0.1337
# 43/43 [==============================] - 1s 15ms/step - loss: -17228410880.0000 - accuracy: 0.1151
# Accuracy:  0.1337166130542755
# Validation Accuracy:  0.11507052928209305
# Loss:  -16917691392.0
# Validation Loss -17228410880.0

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

image_class = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

train_batches = datagen.flow_from_directory(data_dir_train, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
 )

valid_batches = datagen.flow_from_directory(data_dir_test, 
    target_size = (180,180),
    classes = image_class,
    batch_size = 64
)
# Out:
# Found 2390 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %%
# visualize how your augmentation strategy works for one instance of training image.
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings


model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# In order to make the optimizer converge faster and closest to the global minimum of the loss function, i used an annealing method of the learning rate (LR).
#
# The LR is the step by which the optimizer walks through the 'loss landscape'. The higher LR, the bigger are the steps and the quicker is the convergence. However the sampling is very poor with an high LR and the optimizer could probably fall into a local minima.

# %%
# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
batch_size = 10
history = model.fit(train_batches,
  epochs = epochs, verbose = 1, validation_data=valid_batches , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/20
# 38/38 [==============================] - 74s 2s/step - loss: 29.1724 - accuracy: 0.3435 - val_loss: 1.5377 - val_accuracy: 0.2500 - lr: 0.0010
# Epoch 2/20
# 38/38 [==============================] - 67s 2s/step - loss: 1.1484 - accuracy: 0.3745 - val_loss: 1.3342 - val_accuracy: 0.3542 - lr: 0.0010
# Epoch 3/20
# 38/38 [==============================] - 67s 2s/step - loss: 1.1338 - accuracy: 0.3799 - val_loss: 1.2345 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/20
# 38/38 [==============================] - 66s 2s/step - loss: 1.0124 - accuracy: 0.4937 - val_loss: 1.2147 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/20
# 38/38 [==============================] - 67s 2s/step - loss: 0.8958 - accuracy: 0.5887 - val_loss: 1.2402 - val_accuracy: 0.4167 - lr: 0.0010
# Epoch 6/20
# 38/38 [==============================] - 66s 2s/step - loss: 0.8247 - accuracy: 0.6100 - val_loss: 1.2999 - val_accuracy: 0.5208 - lr: 0.0010
# Epoch 7/20
# 38/38 [==============================] - 65s 2s/step - loss: 0.7913 - accuracy: 0.6477 - val_loss: 1.1517 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 8/20
# 38/38 [==============================] - 65s 2s/step - loss: 0.7697 - accuracy: 0.6510 - val_loss: 1.2247 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 9/20
# 38/38 [==============================] - 66s 2s/step - loss: 0.7912 - accuracy: 0.6473 - val_loss: 1.1477 - val_accuracy: 0.6042 - lr: 0.0010
# Epoch 10/20
# 38/38 [==============================] - 65s 2s/step - loss: 0.7612 - accuracy: 0.6498 - val_loss: 1.1608 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 11/20
# 38/38 [==============================] - 65s 2s/step - loss: 0.7286 - accuracy: 0.6682 - val_loss: 1.1451 - val_accuracy: 0.5417 - lr: 0.0010
# Epoch 12/20
# 38/38 [==============================] - ETA: 0s - loss: 0.7091 - accuracy: 0.6649
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 38/38 [==============================] - 66s 2s/step - loss: 0.7091 - accuracy: 0.6649 - val_loss: 1.0820 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 13/20
# 38/38 [==============================] - 66s 2s/step - loss: 0.6704 - accuracy: 0.7021 - val_loss: 1.0619 - val_accuracy: 0.5417 - lr: 5.0000e-04
# Epoch 14/20
# 38/38 [==============================] - 66s 2s/step - loss: 0.6428 - accuracy: 0.7025 - val_loss: 1.0190 - val_accuracy: 0.6042 - lr: 5.0000e-04
# Epoch 15/20
# 38/38 [==============================] - ETA: 0s - loss: 0.6641 - accuracy: 0.6962
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 38/38 [==============================] - 66s 2s/step - loss: 0.6641 - accuracy: 0.6962 - val_loss: 1.1262 - val_accuracy: 0.5625 - lr: 5.0000e-04
# Epoch 16/20
# 38/38 [==============================] - 66s 2s/step - loss: 0.6531 - accuracy: 0.7134 - val_loss: 1.1137 - val_accuracy: 0.5625 - lr: 2.5000e-04
# Epoch 17/20
# 38/38 [==============================] - 67s 2s/step - loss: 0.6277 - accuracy: 0.7151 - val_loss: 1.0812 - val_accuracy: 0.5417 - lr: 2.5000e-04
# Epoch 18/20
# 38/38 [==============================] - ETA: 0s - loss: 0.6213 - accuracy: 0.7109
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 38/38 [==============================] - 66s 2s/step - loss: 0.6213 - accuracy: 0.7109 - val_loss: 1.0822 - val_accuracy: 0.5833 - lr: 2.5000e-04
# Epoch 19/20
# 38/38 [==============================] - 67s 2s/step - loss: 0.6049 - accuracy: 0.7318 - val_loss: 1.0783 - val_accuracy: 0.5417 - lr: 1.2500e-04
# Epoch 20/20
# 38/38 [==============================] - 68s 2s/step - loss: 0.6160 - accuracy: 0.7247 - val_loss: 1.1126 - val_accuracy: 0.5625 - lr: 1.2500e-04

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
print(history.history.keys, ":")
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# <built-in method keys of dict object at 0x7f2012ce2cd0> :

# %% [markdown]
# #### Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
import matplotlib.pyplot as plt
data = dict()

for i in class_names:
  data[i] = []

plt.figure(figsize=(10, 10))
for images, labels in train_ds:
  for i in range(9):
    data[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))

for i in data:
  data[i] = len(data[i]) 

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.bar(range(len(data)), list(data.values()), align='center')
plt.xticks(range(len(data)), list(data.keys()))
plt.show()

# %% [markdown]
# #### Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %% [markdown]
# #### - Which class has the least number of samples? - **Actinic Keratosos** and **Seborrheic keratosis**
# #### - Which classes dominate the data in terms proportionate number of samples?
# **Pigmented benign keratosis** dominates the data of count more than 100 in training

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.7/dist-packages (0.2.10)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/"
# data_dir_train = pathlib.Path(root_path + '/Train')
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1FECCD3110>: 100%|██████████| 500/500 [00:19<00:00, 25.65 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1FECC981D0>: 100%|██████████| 500/500 [00:21<00:00, 23.17 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1FECFF2450>: 100%|██████████| 500/500 [00:22<00:00, 22.45 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7F202622CB10>: 100%|██████████| 500/500 [01:34<00:00,  5.27 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F202622CB10>: 100%|██████████| 500/500 [01:30<00:00,  5.55 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1FECD28E50>: 100%|██████████| 500/500 [00:18<00:00, 27.17 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F1FECD127D0>: 100%|██████████| 500/500 [00:40<00:00, 12.28 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1FECFC18D0>: 100%|██████████| 500/500 [00:18<00:00, 27.63 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F202622CB10>: 100%|██████████| 500/500 [00:17<00:00, 27.86 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 9000

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0029391.jpg_9ad96724-7732-403e-81ee-ed754b5f1826.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031442.jpg_4a4880af-dc19-45de-8c68-7b93f8de9691.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0026433.jpg_7fa4d6e4-e477-4dee-a00a-e6cc2cc12afe.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028928.jpg_f67d69fc-a1be-44ef-9afe-1aa61f5af5d8.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028050.jpg_7f61ee7d-dd38-4a61-ac83-593c7d420c81.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028050.jpg_aa4b948b-7df3-4cd8-913b-f7619e8a7fa3.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0029391.jpg_4061f0fc-825b-4a0f-9a5d-1717119844db.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0026350.jpg_8ae00d47-e90d-4166-b1d4-29e119ecf06c.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025576.jpg_30908f67-9aa4-4382-9457-4b542a7bcbeb.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0027546.jpg_b9779f87-7a36-48ee-9c2b-b62dff91eda8.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0030778.jpg_3ade2565-3bc8-4e64-8d4a-92117969fcfa.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0026321.jpg_61bd4ee5-db8a-4b2a-b6b5-e19bcf9d3908.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031378.jpg_b71321b9-1bff-4ff8-96bf-e747ad74d659.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028035.jpg_c1276b42-6597-407e-8e02-deafc0d2afcb.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0027117.jpg_d6e24896-ed0b-4ff5-974e-bae1593f16ca.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028050.jpg_6dc75df2-4890-436c-8fab-1729efd9671b.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028238.jpg_200c7761-3661-4f0f-981b-340bd85c5bd9.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0027004.jpg_d8c3f21e-5287-472f-a731-654fb253fd22.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0027038.jpg_02944add-d5c3-4c55-a11c-7d8f8d865f17.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0028168.jpg_d61fdec3-152e-4fa1-8fe8-cdcd8d7ca18c.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0
jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025285.jpg_bdc79d48-c914-4d46-9d4a-9bd578fbb22c.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0031062.jpg_e353dd74-f991-4129-bc5d-c2378e7179cf.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025046.jpg_34858630-e95b-4acc-ae27-66b643e94b1c.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0025260.jpg_e23141ec-a332-478d-8af7-7f75bf4e1f8e.jpg',
#  '/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train/basal cell carcinoma/output/basal cell carcinoma_original_ISIC_0029974.jpg_ad284e19-5668-4e55-96c4-a5fbf480df02.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# basal cell carcinoma          1000
# seborrheic keratosis          1000
# actinic keratosis             1000
# melanoma                      1000
# nevus                         1000
# squamous cell carcinoma       1000
# pigmented benign keratosis    1000
# vascular lesion               1000
# dermatofibroma                1000
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
data_dir_train="/content/gdrive/MyDrive/CNN/Skin_Data_Store/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11239 files belonging to 9 classes.
# Using 8992 files for training.

# %% [markdown]
# #### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11239 files belonging to 9 classes.
# Using 2247 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
model = Sequential()

# Increse the model size by adding another 32 layer
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))

# Max Pool size of 2*2
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
# Adding Dropout Layer
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

# %% [markdown]
# ####  Train your model

# %%
epochs = 50

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
    patience=3, 
    verbose=1, 
    factor=0.5, 
    min_lr=0.00001)

batch_size = 10
history = model.fit(train_ds,
  epochs = epochs, verbose = 1, validation_data=val_ds , callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/50
# 281/281 [==============================] - 59s 189ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 0.0010
# Epoch 2/50
# 281/281 [==============================] - 53s 185ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 0.0010
# Epoch 3/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 0.0010
# Epoch 4/50
# 281/281 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1208
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 0.0010
# Epoch 5/50
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 5.0000e-04
# Epoch 6/50
# 281/281 [==============================] - 52s 182ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 5.0000e-04
# Epoch 7/50
# 281/281 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1208
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
[==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 0.1208
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-05.
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.5625e-05
# Epoch 23/50
# 281/281 [==============================] - 52s 180ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 24/50
# 281/281 [==============================] - 52s 180ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 25/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 26/50
# 281/281 [==============================] - 52s 180ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 27/50
# 281/281 [==============================] - 51s 180ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 28/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 29/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 30/50
# 281/281 [==============================] - 52s 182ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 31/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 32/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 33/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 34/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 35/50
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 36/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 37/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 38/50
# 281/281 [==============================] - 52s 180ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 39/50
# 281/281 [==============================] - 51s 180ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 40/50
# 281/281 [==============================] - 52s 180ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 41/50
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 42/50
# 281/281 [==============================] - 52s 181ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 43/50
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 44/50
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 45/50
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 46/50
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 47/50
# 281/281 [==============================] - 51s 178ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 48/50
# 281/281 [==============================] - 51s 178ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 49/50
# 281/281 [==============================] - 51s 178ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05
# Epoch 50/50
# 281/281 [==============================] - 51s 179ms/step - loss: 0.0000e+00 - accuracy: 0.1208 - val_loss: 0.0000e+00 - val_accuracy: 0.1291 - lr: 1.0000e-05

# %% [markdown]
# ####  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# The class rebalance helped in reducing overfititng of the data and thus the loass is beng reduced
# But it reduced the Acurracy very low
#
#
# Initially we tried without the ImageDataGenerator which created data to over fit at high ratio
#
# Then we introduced dropout and ImageDataGenerator which reduced the over fit
#
# At last we tried Batch Normalization and Augumentation which really helped in carry forward
